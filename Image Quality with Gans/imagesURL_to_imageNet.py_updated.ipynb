# %% [markdown]
# # Convert image read from url in csv file to ImageNet
# ** This file intended to process and transform the filtered input csv file into a formal input for Machine Learning. **
# 1. Get image from reading url from csv file
# 2. Resize image
# 3. Convert image to numpy array with shape: (1, IMSIZE*IMSIZE*3)

# %% [markdown]
# ### 1 - Packages
# - [numpy](www.numpy.org) is the main package for scientific computing with Python.
# - [matplotlib](http://matplotlib.org) is a library to plot graphs in Python.
# - [h5py](http://www.h5py.org) is a common package to interact with a dataset that is stored on an H5 file.
# - [cv2](http://opencv.org/) OpenCV is a library of programming functions mainly aimed at real-time computer vision.

# %%
import csv
import numpy as np
import h5py
import urllib
import cv2

# %% [markdown]
# ### 2 - Image URL to 4-D Numpy Matrix
# #### 2.1 - URL to Image

# %%
# use OpenCV, NumPy, and urllib
def url_to_image(url):
    # download the image, convert it to a NumPy array, and then read
    # it into OpenCV format
    resp = urllib.urlopen(url)
    image = np.asarray(bytearray(resp.read()), dtype="uint8")
    image = cv2.imdecode(image, cv2.IMREAD_COLOR)
    return image

# %% [markdown]
# #### 2.2 - Resize Image

# %%
IMSIZE = 128   # The size of image: option including 32 or 64 or 128 or 256

def resize_image(image):
    #print "resizing images"
    resized_image = cv2.resize(image, (IMSIZE, IMSIZE))
    return resized_image

# %% [markdown]
# #### 2.3 - Convert image to 4 dimensional numpy matrix

# %%
def image_to_array(image):
    array = np.asarray(image)
    #dimension = IMSIZE*IMSIZE*3
    return array.reshape(1, IMSIZE, IMSIZE, 3)

# %% [markdown]
# ### This for test: Test 3 examples, concatenate the results

# %%
# This is for Test
# first 3 rows of data
with open('../outside_front_4000.csv', 'rU') as f:
    readCSV = csv.reader(f, delimiter=',')
    imageNet_array = []
    
    i =0
    for row in readCSV:
        # Try 20 samples
        if i<=2:
            label = row[0]
            imageURL = row[1]
            i = i+1
            print "downloading %s" % (imageURL)
            image = url_to_image(imageURL)
            
            print "resizing images"
            resized_image = resize_image(image)
            #cv2.imshow("resizedImage", resized_image)       

            img_array = image_to_array(resized_image)
            print(img_array.shape)
            print("image matrix: ", img_array)

            if len(imageNet_array) == 0:
                imageNet_array = img_array
                print("length is 0")
                print(imageNet_array)
            else:
                imageNet_array = np.concatenate([imageNet_array, img_array])
# Out:
# downloading https://tookan.s3.amazonaws.com/task_images/xaOq1502152810748-TOOKAN08082017104003.jpg
# resizing images
# (1, 49152)
# ('image matrix: ', array([[121, 108, 107, ...,  41,  31,  34]], dtype=uint8))
# length is 0
# [[121 108 107 ...,  41  31  34]]
# downloading https://tookan.s3.amazonaws.com/task_images/jfVf1502174230389-photoName.jpeg
# resizing images
# (1, 49152)
# ('image matrix: ', array([[81, 89, 88, ..., 27, 24, 33]], dtype=uint8))
# downloading https://tookan.s3.amazonaws.com/task_images/0T1r1502174379338-photoName.jpeg
# resizing images
# (1, 49152)
# ('image matrix: ', array([[209, 220, 234, ...,  40,  46,  53]], dtype=uint8))

# %%
print("result:") 
print(imageNet_array)
print("shape:")          
print(imageNet_array.shape)
# Out:
# result:
# [[121 108 107 ...,  41  31  34]
#  [ 81  89  88 ...,  27  24  33]
#  [209 220 234 ...,  40  46  53]]
# shape:
# (3, 49152)

# %%
# Save numpy array as .npy file 
# Number of Rows: the number of images (nx of training set)
# Number of Columns: features of an image    
np.save('testfile.npy', imageNet_array)
d = np.load('testfile.npy')
print(d.shape)
print(imageNet_array == d)
# Out:
# (3, 49152)
# [[ True  True  True ...,  True  True  True]
#  [ True  True  True ...,  True  True  True]
#  [ True  True  True ...,  True  True  True]]

# %% [markdown]
# ### This is convert 10000 fontside image to arrayNets
# **imageNet_array: Concatenated result of 1000 images **

# %%
import time

start = time.time()
#print("Start processing")

with open('../images/outside_front.csv', 'rU') as f:
    readCSV = csv.reader(f, delimiter=',')
    interestingrows = [row for idx, row in enumerate(readCSV) if idx in list(range(0,12329))]
    
    imageNet_array = []

    print("Start Processing")
    i = 0
    for row in interestingrows:
        #label = row[0]
        imageURL = row[1]
        i = i+1
        #print(str(i)+"th image:" + str())
        
        #print "%s th: downloading %s" % (i, imageURL)
        image = url_to_image(imageURL)
            
#        print "resizing images"
        resized_image = resize_image(image)

        img_array = image_to_array(resized_image)
#        print(img_array.shape)

        if i % 120 == 0:
            print("Processed the "+str(i)+"th image.")
#             print("image matrix: " + str(img_array))

        if len(imageNet_array) == 0:
            imageNet_array = img_array
#            print("length is 0")
#            print(imageNet_array)
        else:
            imageNet_array = np.concatenate([imageNet_array, img_array])
            
end = time.time()
print("Complete processing:")
print(end - start)
# Out:
# Start Processing
# Processed the 120th image.
# Processed the 240th image.
# Processed the 360th image.
# Processed the 480th image.
# Processed the 600th image.
# Processed the 720th image.
# Processed the 840th image.
# Processed the 960th image.
# Processed the 1080th image.
# Processed the 1200th image.
# Processed the 1320th image.
# Processed the 1440th image.
# Processed the 1560th image.
# Processed the 1680th image.
# Processed the 1800th image.
# Processed the 1920th image.
# Processed the 2040th image.
# Processed the 2160th image.
# Processed the 2280th image.
# Processed the 2400th image.
# Processed the 2520th image.
# Processed the 2640th image.
# Processed the 2760th image.
# Processed the 2880th image.
# Processed the 3000th image.
# Processed the 3120th image.
# Processed the 3240th image.
# Processed the 3360th image.
# Processed the 3480th image.
# Processed the 3600th image.
# Processed the 3720th image.
# Processed the 3840th image.
# Processed the 3960th image.
# Processed the 4080th image.
# Processed the 4200th image.
# Processed the 4320th image.
# Processed the 4440th image.
# Processed the 4560th image.
# Processed the 4680th image.
# Processed the 4800th image.
# Processed the 4920th image.
# Processed the 5040th image.
# Processed the 5160th image.
# Processed the 5280th image.
# Processed the 5400th image.
# Processed the 5520th image.
# Processed the 5640th image.
# Processed the 5760th image.
# Processed the 5880th image.
# Processed the 6000th image.
# Processed the 6120th image.
# Processed the 6240th image.
# Processed the 6360th image.
# Processed the 6480th image.
# Processed the 6600th image.
# Processed the 6720th image.
# Processed the 6840th image.
# Processed the 6960th image.
# Processed the 7080th image.
# Processed the 7200th image.
# Processed the 7320th image.
# Processed the 7440th image.
# Processed the 7560th image.
# Processed the 7680th image.
# Processed the 7800th image.
# Processed the 7920th image.
# Processed the 8040th image.
# Processed the 8160th image.
# Processed the 8280th image.
# Processed the 8400th image.
# Processed the 8520th image.
# Processed the 8640th image.
# Processed the 8760th image.
# Processed the 8880th image.
# Processed the 9000th image.
# Processed the 9120th image.
# Processed the 9240th image.
# Processed the 9360th image.
# Processed the 9480th image.
# Processed the 9600th image.
# Processed the 9720th image.
# Processed the 9840th image.
# Processed the 9960th image.
# Processed the 10080th image.
# Processed the 10200th image.
# Processed the 10320th image.
# Processed the 10440th image.
# Processed the 10560th image.
# Processed the 10680th image.
# Processed the 10800th image.
# Processed the 10920th image.
# Processed the 11040th image.
# Processed the 11160th image.
# Processed the 11280th image.
# Processed the 11400th image.
# Processed the 11520th image.
# Processed the 11640th image.
# Processed the 11760th image.
# Processed the 11880th image.
# Processed the 12000th image.
# Processed the 12120th image.
# Processed the 12240th image.
# Complete processing:
# 34383.3246698

# %% [markdown]
# **Method1: Save result to binary file .npy **

# %%
print("result:") 
print(imageNet_array)
print("shape:")          
print(imageNet_array.shape)
# Out:
# result:
# [[[[123 118 120]
#    [127 146 154]
#    [ 96 120 137]
#    ...,
#    [118 116 125]
#    [224 222 231]
#    [228 225 227]]
#
#   [[127 122 124]
#    [131 151 158]
#    [ 87 112 129]
#    ...,
#    [127 132 140]
#    [148 153 161]
#    [129 130 137]]
#
#   [[104  99 100]
#    [121 141 148]
#    [ 91 116 133]
#    ...,
#    [ 53  64  71]
#    [ 55  66  72]
#    [ 92  97 109]]
#
#   ...,
#   [[ 70  72  80]
#    [ 84  86  94]
#    [ 74  76  84]
#    ...,
#    [ 65  71  78]
#    [ 67  73  80]
#    [ 68  70  78]]
#
#   [[ 77  79  87]
#    [ 68  70  78]
#    [ 56  58  66]
#    ...,
#    [110 116 123]
#    [ 62  68  75]
#    [ 62  64  72]]
#
#   [[ 62  65  69]
#    [ 70  73  77]
#    [ 64  67  71]
#    ...,
#    [130 134 145]
#    [ 58  62  73]
#    [ 67  69  77]]]
#
#
#  [[[139 151 170]
#    [117 124 137]
#    [ 85  92 105]
#    ...,
#    [157 150 147]
#    [151 144 141]
#    [ 75  78  82]]
#
#   [[ 58  51  52]
#    [ 49  50  63]
#    [ 78  78  89]
#    ...,
#    [155 148 145]
#    [151 144 141]
#    [ 60  63  67]]
#
#   [[ 69  55  56]
#    [100 110 144]
#    [105 112 142]
#    ...,
#    [153 146 143]
#    [151 144 141]
#    [ 76  80  84]]
#
#   ...,
#   [[147 149 154]
#    [158 161 165]
#    [146 148 152]
#    ...,
#    [129 132 136]
#    [123 126 130]
#    [133 132 136]]
#
#   [[146 149 153]
#    [151 154 158]
#    [151 154 158]
#    ...,
#    [127 130 134]
#    [136 139 143]
#    [130 129 133]]
#
#   [[153 156 160]
#    [149 152 156]
#    [150 153 157]
#    ...,
#    [131 130 134]
#    [134 133 137]
#    [139 138 142]]]
#
#
#  [[[116 128 138]
#    [ 87  99 111]
#    [ 85  96 110]
#    ...,
#    [ 57  69  80]
#    [ 25  35  42]
#    [ 93 110 119]]
#
#   [[127 143 140]
#    [ 80  95 100]
#    [ 92 103 118]
#    ...,
#    [ 28  45  55]
#    [ 23  32  39]
#    [ 44  53  63]]
#
#   [[142 163 147]
#    [164 181 179]
#    [ 75  85 101]
#    ...,
#    [ 30  53  62]
#    [ 44  51  58]
#    [ 67  90  98]]
#
#   ...,
#   [[147 166 174]
#    [147 166 174]
#    [146 165 173]
#    ...,
#    [142 163 178]
#    [145 166 181]
#    [146 162 178]]
#
#   [[142 161 169]
#    [141 160 168]
#    [148 167 176]
#    ...,
#    [146 166 182]
#    [141 162 177]
#    [142 158 174]]
#
#   [[137 155 163]
#    [145 164 172]
#    [144 163 171]
#    ...,
#    [129 150 165]
#    [137 158 173]
#    [141 162 177]]]
#
#
#  ...,
#  [[[115 103  99]
#    [135 123 119]
#    [142 124 122]
#    ...,
#    [203 199 205]
#    [199 195 201]
#    [196 191 193]]
#
#   [[112 101  97]
#    [127 114 107]
#    [135 121 116]
#    ...,
#    [198 198 201]
#    [208 202 207]
#    [ 74  64  64]]
#
#   [[131 116 112]
#    [134 119 116]
#    [136 121 117]
#    ...,
#    [189 186 183]
#    [108 100  99]
#    [ 76  67  64]]
#
#   ...,
#   [[228 233 234]
#    [227 233 238]
#    [226 231 232]
#    ...,
#    [ 28  23  26]
#    [ 30  25  24]
#    [ 30  22  21]]
#
#   [[228 234 239]
#    [226 232 239]
#    [227 231 236]
#    ...,
#    [ 26  23  25]
#    [ 32  26  27]
#    [ 29  24  21]]
#
#   [[225 229 234]
#    [226 231 234]
#    [225 230 234]
#    ...,
#    [ 31  24  25]
#    [ 32  24  25]
#    [ 29  24  21]]]
#
#
#  [[[ 74  68  69]
#    [125 130 129]
#    [ 86  89  89]
#    ...,
#    [225 229 234]
#    [225 229 234]
#    [224 227 235]]
#
#   [[ 56  50  45]
#    [ 61  53  53]
#    [118 123 124]
#    ...,
#    [224 228 233]
#    [223 229 234]
#    [227 231 236]]
#
#   [[ 59  51  47]
#    [ 62  52  52]
#    [121 120 122]
#    ...,
#    [225 227 235]
#    [224 228 233]
#    [226 230 235]]
#
#   ...,
#   [[ 41  40  47]
#    [ 36  36  44]
#    [ 39  41  50]
#    ...,
#    [ 48  76 111]
#    [ 26  50  78]
#    [ 40  49  66]]
#
#   [[ 43  46  54]
#    [ 38  42  47]
#    [ 26  30  34]
#    ...,
#    [ 27  43  73]
#    [ 24  47  82]
#    [ 35  64 103]]
#
#   [[ 37  43  50]
#    [ 41  40  50]
#    [ 39  42  43]
#    ...,
#    [ 17  22  34]
#    [ 11  18  32]
#    [ 32  48  77]]]
#
#
#  [[[136 109 112]
#    [130 108 103]
#    [127 102 100]
#    ...,
#    [ 95 113 139]
#    [ 87 108 129]
#    [ 79  99 124]]
#
#   [[148 126 121]
#    [147 125 120]
#    [144 125 126]
#    ...,
#    [ 74  90 119]
#    [109 126 153]
#    [100 118 144]]
#
#   [[139 119 114]
#    [142 121 117]
#    [150 126 122]
#    ...,
#    [ 87 103 128]
#    [ 90 110 138]
#    [ 86 102 130]]
#
#   ...,
#   [[ 50  49  59]
#    [ 55  49  60]
#    [ 47  39  41]
#    ...,
#    [ 44  38  43]
#    [ 45  39  44]
#    [ 61  54  63]]
#
#   [[ 41  40  50]
#    [ 52  50  60]
#    [ 52  49  57]
#    ...,
#    [ 40  35  42]
#    [ 56  52  58]
#    [ 60  52  59]]
#
#   [[ 49  48  58]
#    [ 52  46  57]
#    [ 49  44  54]
#    ...,
#    [ 44  41  44]
#    [ 55  48  55]
#    [ 64  54  60]]]]
# shape:
# (12329, 128, 128, 3)

# %%
# Save numpy array as .npy file 
# Number of Rows: the number of images (nx of training set)
# Number of Columns: features of an image 

# np.save('1000_image.npy', imageNet_array)
# d = np.load('1000_image.npy')
np.save('12330_outside_front.npy', imageNet_array)
d = np.load('12330_outside_front.npy')
print(d.shape)
print(imageNet_array == d)
# Out:
# (12329, 128, 128, 3)
# [[[[ True  True  True]
#    [ True  True  True]
#    [ True  True  True]
#    ...,
#    [ True  True  True]
#    [ True  True  True]
#    [ True  True  True]]
#
#   [[ True  True  True]
#    [ True  True  True]
#    [ True  True  True]
#    ...,
#    [ True  True  True]
#    [ True  True  True]
#    [ True  True  True]]
#
#   [[ True  True  True]
#    [ True  True  True]
#    [ True  True  True]
#    ...,
#    [ True  True  True]
#    [ True  True  True]
#    [ True  True  True]]
#
#   ...,
#   [[ True  True  True]
#    [ True  True  True]
#    [ True  True  True]
#    ...,
#    [ True  True  True]
#    [ True  True  True]
#    [ True  True  True]]
#
#   [[ True  True  True]
#    [ True  True  True]
#    [ True  True  True]
#    ...,
#    [ True  True  True]
#    [ True  True  True]
#    [ True  True  True]]
#
#   [[ True  True  True]
#    [ True  True  True]
#    [ True  True  True]
#    ...,
#    [ True  True  True]
#    [ True  True  True]
#    [ True  True  True]]]
#
#
#  [[[ True  True  True]
#    [ True  True  True]
#    [ True  True  True]
#    ...,
#    [ True  True  True]
#    [ True  True  True]
#    [ True  True  True]]
#
#   [[ True  True  True]
#    [ True  True  True]
#    [ True  True  True]
#    ...,
#    [ True  True  True]
#    [ True  True  True]
#    [ True  True  True]]
#
#   [[ True  True  True]
#    [ True  True  True]
#    [ True  True  True]
#    ...,
#    [ True  True  True]
#    [ True  True  True]
#    [ True  True  True]]
#
#   ...,
#   [[ True  True  True]
#    [ True  True  True]
#    [ True  True  True]
#    ...,
#    [ True  True  True]
#    [ True  True  True]
#    [ True  True  True]]
#
#   [[ True  True  True]
#    [ True  True  True]
#    [ True  True  True]
#    ...,
#    [ True  True  True]
#    [ True  True  True]
#    [ True  True  True]]
#
#   [[ True  True  True]
#    [ True  True  True]
#    [ True  True  True]
#    ...,
#    [ True  True  True]
#    [ True  True  True]
#    [ True  True  True]]]
#
#
#  [[[ True  True  True]
#    [ True  True  True]
#    [ True  True  True]
#    ...,
#    [ True  True  True]
#    [ True  True  True]
#    [ True  True  True]]
#
#   [[ True  True  True]
#    [ True  True  True]
#    [ True  True  True]
#    ...,
#    [ True  True  True]
#    [ True  True  True]
#    [ True  True  True]]
#
#   [[ True  True  True]
#    [ True  True  True]
#    [ True  True  True]
#    ...,
#    [ True  True  True]
#    [ True  True  True]
#    [ True  True  True]]
#
#   ...,
#   [[ True  True  True]
#    [ True  True  True]
#    [ True  True  True]
#    ...,
#    [ True  True  True]
#    [ True  True  True]
#    [ True  True  True]]
#
#   [[ True  True  True]
#    [ True  True  True]
#    [ True  True  True]
#    ...,
#    [ True  True  True]
#    [ True  True  True]
#    [ True  True  True]]
#
#   [[ True  True  True]
#    [ True  True  True]
#    [ True  True  True]
#    ...,
#    [ True  True  True]
#    [ True  True  True]
#    [ True  True  True]]]
#
#
#  ...,
#  [[[ True  True  True]
#    [ True  True  True]
#    [ True  True  True]
#    ...,
#    [ True  True  True]
#    [ True  True  True]
#    [ True  True  True]]
#
#   [[ True  True  True]
#    [ True  True  True]
#    [ True  True  True]
#    ...,
#    [ True  True  True]
#    [ True  True  True]
#    [ True  True  True]]
#
#   [[ True  True  True]
#    [ True  True  True]
#    [ True  True  True]
#    ...,
#    [ True  True  True]
#    [ True  True  True]
#    [ True  True  True]]
#
#   ...,
#   [[ True  True  True]
#    [ True  True  True]
#    [ True  True  True]
#    ...,
#    [ True  True  True]
#    [ True  True  True]
#    [ True  True  True]]
#
#   [[ True  True  True]
#    [ True  True  True]
#    [ True  True  True]
#    ...,
#    [ True  True  True]
#    [ True  True  True]
#    [ True  True  True]]
#
#   [[ True  True  True]
#    [ True  True  True]
#    [ True  True  True]
#    ...,
#    [ True  True  True]
#    [ True  True  True]
#    [ True  True  True]]]
#
#
#  [[[ True  True  True]
#    [ True  True  True]
#    [ True  True  True]
#    ...,
#    [ True  True  True]
#    [ True  True  True]
#    [ True  True  True]]
#
#   [[ True  True  True]
#    [ True  True  True]
#    [ True  True  True]
#    ...,
#    [ True  True  True]
#    [ True  True  True]
#    [ True  True  True]]
#
#   [[ True  True  True]
#    [ True  True  True]
#    [ True  True  True]
#    ...,
#    [ True  True  True]
#    [ True  True  True]
#    [ True  True  True]]
#
#   ...,
#   [[ True  True  True]
#    [ True  True  True]
#    [ True  True  True]
#    ...,
#    [ True  True  True]
#    [ True  True  True]
#    [ True  True  True]]
#
#   [[ True  True  True]
#    [ True  True  True]
#    [ True  True  True]
#    ...,
#    [ True  True  True]
#    [ True  True  True]
#    [ True  True  True]]
#
#   [[ True  True  True]
#    [ True  True  True]
#    [ True  True  True]
#    ...,
#    [ True  True  True]
#    [ True  True  True]
#    [ True  True  True]]]
#
#
#  [[[ True  True  True]
#    [ True  True  True]
#    [ True  True  True]
#    ...,
#    [ True  True  True]
#    [ True  True  True]
#    [ True  True  True]]
#
#   [[ True  True  True]
#    [ True  True  True]
#    [ True  True  True]
#    ...,
#    [ True  True  True]
#    [ True  True  True]
#    [ True  True  True]]
#
#   [[ True  True  True]
#    [ True  True  True]
#    [ True  True  True]
#    ...,
#    [ True  True  True]
#    [ True  True  True]
#    [ True  True  True]]
#
#   ...,
#   [[ True  True  True]
#    [ True  True  True]
#    [ True  True  True]
#    ...,
#    [ True  True  True]
#    [ True  True  True]
#    [ True  True  True]]
#
#   [[ True  True  True]
#    [ True  True  True]
#    [ True  True  True]
#    ...,
#    [ True  True  True]
#    [ True  True  True]
#    [ True  True  True]]
#
#   [[ True  True  True]
#    [ True  True  True]
#    [ True  True  True]
#    ...,
#    [ True  True  True]
#    [ True  True  True]
#    [ True  True  True]]]]

# %% [markdown]
# ### Method2: Save result to h5py fromat

# %%
import h5py

#hf = h5py.File('data.h5','w')
#hf.create_dataset('outside_front_1000', data = imageNet_array)
hf = h5py.File('data.h5','r+')
hf.create_dataset('wipehero_outside_front_12330', data = imageNet_array, compression="gzip", compression_opts=9) # can compress the data

hf.close()

# %% [markdown]
# ##### Reading HDF5 files

# %%
h5f = h5py.File('data.h5','r')
#data1 = h5f['outside_front_1000'][:]
data2 = h5f['wipehero_outside_front_12330'][:]


h5f.close()

# %%
np.allclose(imageNet_array,data2)
# Out:
# True

# %%
print(data2.shape)
# Out:
# (12329, 128, 128, 3)
